# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target,
                                                    stratify=cancer.target,
                                                   random_state=42)
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)
print("Accuracy on training set: " , tree.score(X_train, y_train))
print("Accuracy on Test set: " , tree.score(X_test, y_test))
# Out:
# Accuracy on training set:  1.0
# Accuracy on Test set:  0.9370629370629371

# %%
# now we train new tree with prune levels, knnneighbors 
# and maxdepth are hyperparameters
tree = DecisionTreeClassifier(random_state=0, max_depth=4)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=0)

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print("Accuracy on training set: " , tree.score(X_train, y_train))
print("Accuracy on Test set: " , tree.score(X_test, y_test))
# Out:
# Accuracy on training set:  0.9882629107981221
# Accuracy on Test set:  0.951048951048951

# %%
# this is to make visualise the model, like a decision tree
from sklearn.tree import export_graphviz
dot_data = export_graphviz(tree,class_names=['Malignant','benign'],
        feature_names=cancer.feature_names , impurity=False, filled=True)
import graphviz
display(graphviz.Source(dot_data))
